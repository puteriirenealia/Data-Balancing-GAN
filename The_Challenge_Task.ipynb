# %% [markdown]
# <a href="https://colab.research.google.com/github/puteriirenealia/Data-Balancing-GAN/blob/main/The_Challenge_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to the Challenge ⭐
#
# In this challenge, we are going to assist a group of biologists who are attempting to classify a group of mice into different categories.🐁
#
#  They have observed that the data they possess is imbalanced in terms of class distribution. Therefore, they are employing Generative AI to generate synthetic data. They have reached out to us as data scientists to aid in the development of a monitoring system. This system will allow them to assess the performance of their generative model at each stage of training.
#
# To assist them, we will be implementing a Python method that utilizes PCA (Principal Component Analysis) to reduce the dimensionality of the data. This reduction in dimensionality will help us visualize the data in a lower-dimensional space.

# %%
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the dataset

# %%
data = pd.read_csv("/content/Challenge_task_data.csv")
data.head()
# Out:
#    Prolactin  Testosterone  Estradiol    Ghrelin     Leptin  Growth Hormone  \
# 0   0.754120     29.189123  42.044310  37.567998  73.985142        6.608973
# 1   8.158490     32.509354  12.501241  51.133068  70.606907       12.747177
# 2   6.424000     36.250426  36.849968  34.055306  53.386626        2.649511
# 3   8.153998     27.654827  37.955131  54.439626  58.785287       12.935813
# 4  14.526488     31.049499  27.867318  16.539515  59.786112        8.432827
#
#    Thyroid hormones   Cortisol   Glucagon    Insulin  Group
# 0         33.106004  40.453011  57.624448  25.980636      0
# 1         15.574375  49.405004  69.978084  23.605471      0
# 2         12.324845  32.898348  58.742648  37.935118      0
# 3         13.913423  57.329415  52.019237  33.970979      0
# 4         26.605085  44.158559  40.299767  42.197797      0

# %% [markdown]
# Create two variables `X` and `y`. Seperate the feature columns and `Group` column.
#
# Store the  feature columns in `X` and the `Group` column in `y`

# %%
X = data.drop('Group', axis = 1)
y = data.Group

# %% [markdown]
# Write a method called `PCA_Visualization(features, labels)`:
#
# * This method will apply a Principal Component Analysis to the `features` to reduce the data dimensionality to `2` features.
# * Convert the transformed data into a dataframe
# * Use seaborn scatter plot to visualize the data points.apply colors to different groups of data points `(hue = 'Group')`
# * visualize the data using the method

# %%
pca = PCA(2)
transformed_data = pca.fit_transform(X)
df = pd.DataFrame(transformed_data)
df['Group'] = y
df
# Out:
#               0          1  Group
# 0    -37.577977  64.655454      0
# 1    -41.754851  60.672453      0
# 2    -49.756487  61.216223      0
# 3    -43.424454  60.801065      0
# 4    -43.351300  57.876447      0
# ...         ...        ...    ...
# 4784  70.224229  23.139041      2
# 4785 -70.585069  -4.225533      1
# 4786  59.114962  -5.401757      2
# 4787 -57.302140   7.181056      1
# 4788 -53.020335 -23.176958      1
#
# [4789 rows x 3 columns]

# %%
sns.scatterplot (df, x=0, y=1, hue='Group')
# Out:
# <Axes: xlabel='0', ylabel='1'>
